# %%
import pandas as pd

# %%
bike_data_to_load = "JC-201908-citibike-tripdata.csv"
bike_data_df = pd.read_csv(bike_data_to_load)
bike_data_df.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           261   14:56.0  19:17.5              3205  JC Medical Center
# 1           172   23:07.0  25:59.1              3279        Dixon Mills
# 2           525   23:28.6  32:13.7              3199       Newport Pkwy
# 3           219   32:36.1  36:15.3              3187          Warren St
# 4           262   41:26.7  45:49.4              3186      Grove St PATH
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716540               -74.049638            3192
# 1               40.721630               -74.049968            3186
# 2               40.728745               -74.032108            3203
# 3               40.721124               -74.038051            3185
# 4               40.719586               -74.043117            3272
#
#      end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
bike_data_df['tripduration'] = pd.to_datetime(bike_data_df["tripduration"], unit='s')
bike_data_df.head()
# Out:
#          tripduration starttime stoptime  start station id start station name  \
# 0 1970-01-01 00:04:21   14:56.0  19:17.5              3205  JC Medical Center
# 1 1970-01-01 00:02:52   23:07.0  25:59.1              3279        Dixon Mills
# 2 1970-01-01 00:08:45   23:28.6  32:13.7              3199       Newport Pkwy
# 3 1970-01-01 00:03:39   32:36.1  36:15.3              3187          Warren St
# 4 1970-01-01 00:04:22   41:26.7  45:49.4              3186      Grove St PATH
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716540               -74.049638            3192
# 1               40.721630               -74.049968            3186
# 2               40.728745               -74.032108            3203
# 3               40.721124               -74.038051            3185
# 4               40.719586               -74.043117            3272
#
#      end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
bike_data_df.to_csv('201908-citibike-tripdata-CONVERTED.csv',index=False)
